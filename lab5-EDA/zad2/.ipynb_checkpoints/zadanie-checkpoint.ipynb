# %%
import pandas as pd
import matplotlib.pyplot as plt

print('W jakich państwach poziom demokracji w opisywanych latach był stały, ciągle malejący, ciągle rosnący dla pozostałych określ czy poziom demokracji miał tendencję wzrostową czy malejącą?')

df = pd.read_csv('dem_score.csv', delimiter=';')
df
df.info()
df.describe(include='all')
df_const = pd.melt(df, id_vars=['country'], value_vars=['1952','1957','1962','1967','1972','1977','1982','1987','1992'])
df_const.sort_values(by=['country','variable'])
# Out:
# W jakich państwach poziom demokracji w opisywanych latach był stały, ciągle malejący, ciągle rosnący dla pozostałych określ czy poziom demokracji miał tendencję wzrostową czy malejącą?
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 10 columns):
# country    96 non-null object
# 1952       96 non-null int64
# 1957       96 non-null int64
# 1962       96 non-null int64
# 1967       96 non-null int64
# 1972       96 non-null int64
# 1977       96 non-null int64
# 1982       96 non-null int64
# 1987       96 non-null int64
# 1992       96 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 7.6+ KB
#            country variable  value
# 0          Albania     1952     -9
# 96         Albania     1957     -9
# 192        Albania     1962     -9
# 288        Albania     1967     -9
# 384        Albania     1972     -9
# 480        Albania     1977     -9
# 576        Albania     1982     -9
# 672        Albania     1987     -9
# ...
